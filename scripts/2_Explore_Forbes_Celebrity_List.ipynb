# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read in data from CSV file

# %%
file_name = '../input/forbes_celebrity_list.csv'

# %%
df = pd.read_csv(file_name)

# %%
# ?pd.read_csv

# %%
df
# Out:
#      year  rank          recipient              country  \
# 0    1999     1     Michael Jordan        United States
# 1    1999     2      Oprah Winfrey        United States
# 2    1999     3  Leonardo DiCaprio        United States
# 3    1999     4     Jerry Seinfeld        United States
# 4    1999     5   Steven Spielberg        United States
# ..    ...   ...                ...                  ...
# 197  2018     6                 U2  Republic of Ireland
# 198  2018     7           Coldplay       United Kingdom
# 199  2018     8       Lionel Messi            Argentina
# 200  2018     9         Ed Sheeran       United Kingdom
# 201  2018    10  Cristiano Ronaldo             Portugal
#
#                              career  tied              title
# 0         Sportsperson (Basketball)     0     Michael_Jordan
# 1            Television Personality     0      Oprah_Winfrey
# 2                             Actor     0  Leonardo_DiCaprio
# ...

# %%
df.head()
# Out:
#    year  rank          recipient        country                     career  \
# 0  1999     1     Michael Jordan  United States  Sportsperson (Basketball)
# 1  1999     2      Oprah Winfrey  United States     Television Personality
# 2  1999     3  Leonardo DiCaprio  United States                      Actor
# 3  1999     4     Jerry Seinfeld  United States                      Actor
# 4  1999     5   Steven Spielberg  United States                  Filmmaker
#
#    tied              title
# 0     0     Michael_Jordan
# 1     0      Oprah_Winfrey
# 2     0  Leonardo_DiCaprio
# 3     0     Jerry_Seinfeld
# 4     0   Steven_Spielberg

# %%
df.head(10)
# Out:
#    year  rank           recipient         country                     career  \
# 0  1999     1      Michael Jordan   United States  Sportsperson (Basketball)
# 1  1999     2       Oprah Winfrey   United States     Television Personality
# 2  1999     3   Leonardo DiCaprio   United States                      Actor
# 3  1999     4      Jerry Seinfeld   United States                      Actor
# 4  1999     5    Steven Spielberg   United States                  Filmmaker
# 5  1999     6         Spice Girls  United Kingdom                  Musicians
# 6  1999     7       Harrison Ford   United States                      Actor
# 7  1999     8      Robin Williams   United States                      Actor
# 8  1999     9         Celine Dion          Canada                   Musician
# 9  1999    10  The Rolling Stones  United Kingdom                  Musicians
#
#    tied               title
# 0     0      Michael_Jordan
# 1     0       Oprah_Winfrey
# 2     0   Leonardo_DiCaprio
# ...

# %% [markdown]
# ### Filtering

# %%
df[df['tied']==1]
# Out:
#      year  rank   recipient        country                  career  tied  \
# 41   2003     2      Eminem  United States               Musicians     1
# 42   2003     2     Dr. Dre  United States               Musicians     1
# 100  2008    10   Brad Pitt  United States                   Actor     1
# 101  2008    10  Paula Deen  United States  Television Personality     1
#
#           title
# 41       Eminem
# 42      Dr._Dre
# 100   Brad_Pitt
# 101  Paula_Deen

# %%
df[['tied', 'title']].loc[0, 'title']
# Out:
# 'Michael_Jordan'

# %%
df['career'].value_counts()
# Out:
# Musician                               52
# Actor                                  37
# Musicians                              26
# Television Personality                 23
# Filmmaker                              14
# Sportsperson (Golf)                    12
# Sportsperson (Basketball)              10
# Author                                  7
# Sportsperson (Association Football)     5
# Radio Personality                       4
# Sportsperson (Boxing)                   3
# Athlete (Association football)          2
# Musician / Actor                        2
# Personality                             2
# Athlete (Boxing)                        1
# Sportsperson (Tennis)                   1
# Actors                                  1
# Name: career, dtype: int64

# %%
df.head()
# Out:
#    year  rank          recipient        country                     career  \
# 0  1999     1     Michael Jordan  United States  Sportsperson (Basketball)
# 1  1999     2      Oprah Winfrey  United States     Television Personality
# 2  1999     3  Leonardo DiCaprio  United States                      Actor
# 3  1999     4     Jerry Seinfeld  United States                      Actor
# 4  1999     5   Steven Spielberg  United States                  Filmmaker
#
#    tied              title
# 0     0     Michael_Jordan
# 1     0      Oprah_Winfrey
# 2     0  Leonardo_DiCaprio
# 3     0     Jerry_Seinfeld
# 4     0   Steven_Spielberg

# %%
df['year'].value_counts()
# Out:
# 2008    11
# 2003    11
# 2017    10
# 2000    10
# 2001    10
# 2002    10
# 2004    10
# 2005    10
# 2006    10
# 2007    10
# 2018    10
# 2009    10
# 2010    10
# 2011    10
# 2012    10
# 2013    10
# 2014    10
# 2015    10
# 2016    10
# 1999    10
# Name: year, dtype: int64

# %%
df[(df['year'] == 2015) & (df['country'] == 'Philippines')]
# Out:
#      year  rank       recipient      country                 career  tied  \
# 163  2015     2  Manny Pacquiao  Philippines  Sportsperson (Boxing)     0
#
#               title
# 163  Manny_Pacquiao

# %%
df[df['career'].str.contains('Boxing')]
# Out:
#      year  rank              recipient        country                 career  \
# 158  2014     7  Floyd Mayweather, Jr.  United States  Sportsperson (Boxing)
# 162  2015     1  Floyd Mayweather, Jr.  United States  Sportsperson (Boxing)
# 163  2015     2         Manny Pacquiao    Philippines  Sportsperson (Boxing)
# 192  2018     1  Floyd Mayweather, Jr.  United States       Athlete (Boxing)
#
#      tied                 title
# 158     0  Floyd_Mayweather_Jr.
# 162     0  Floyd_Mayweather_Jr.
# 163     0        Manny_Pacquiao
# 192     0  Floyd_Mayweather_Jr.

# %%
df['career'].str.split(' ')
# Out:
# 0            [Sportsperson, (Basketball)]
# 1               [Television, Personality]
# 2                                 [Actor]
# 3                                 [Actor]
# 4                             [Filmmaker]
#                       ...
# 197                           [Musicians]
# 198                           [Musicians]
# 199    [Athlete, (Association, football)]
# 200                            [Musician]
# 201    [Athlete, (Association, football)]
# Name: career, Length: 202, dtype: object

# %%
df['recipient'].value_counts().index
# Out:
# Index(['Oprah Winfrey', 'Tiger Woods', 'Steven Spielberg', 'Madonna',
#        'The Rolling Stones', 'Beyonce', 'Tom Cruise', 'Johnny Depp',
#        'Michael Jordan', 'U2', 'Lady Gaga', 'Taylor Swift',
#        'Cristiano Ronaldo', 'Britney Spears', 'Howard Stern', 'Jay-Z',
#        'Katy Perry', 'Floyd Mayweather, Jr.', 'Tom Hanks', 'James Patterson',
#        'J. K. Rowling', 'Mel Gibson', 'Justin Bieber', 'Brad Pitt',
#        'Elton John', 'LeBron James', 'Rihanna', 'Dr. Dre', 'George Lucas',
#        'Coldplay', 'Robert Downey, Jr.', 'NSYNC', 'One Direction',
#        'Lionel Messi', 'Backstreet Boys', 'Jennifer Lopez', 'Ellen DeGeneres',
#        'Angelina Jolie', 'Bon Jovi', 'Jennifer Aniston', 'Bruce Springsteen',
#        'Rush Limbaugh', 'Kim Kardashian', 'Mariah Carey', '50 Cent',
#        'Paul McCartney', 'David Beckham', 'Leonardo DiCaprio', 'Dan Brown',
#        'Sean 'Diddy' Combs', 'Dwayne Johnson', 'Cher', 'Harrison Ford',
# ...

# %% [markdown]
# ### Sorting

# %%
df.sort_values(by=['rank', 'year'], ascending=[True, False]).head(5)
# Out:
#      year  rank              recipient        country                 career  \
# 192  2018     1  Floyd Mayweather, Jr.  United States       Athlete (Boxing)
# 182  2017     1     Sean 'Diddy' Combs  United States               Musician
# 172  2016     1           Taylor Swift  United States               Musician
# 162  2015     1  Floyd Mayweather, Jr.  United States  Sportsperson (Boxing)
# 152  2014     1                Beyonce  United States               Musician
#
#      tied                 title
# 192     0  Floyd_Mayweather_Jr.
# 182     0            Sean_Combs
# 172     0          Taylor_Swift
# 162     0  Floyd_Mayweather_Jr.
# 152     0               Beyoncé

# %%
df[df['rank']<=5].sort_values(by=['year', 'rank'], ascending=[False, True])
# Out:
#      year  rank              recipient        country  \
# 192  2018     1  Floyd Mayweather, Jr.  United States
# 193  2018     2         George Clooney  United States
# 194  2018     3           Kylie Jenner  United States
# 195  2018     4         Judy Sheindlin  United States
# 196  2018     5         Dwayne Johnson  United States
# ..    ...   ...                    ...            ...
# 0    1999     1         Michael Jordan  United States
# 1    1999     2          Oprah Winfrey  United States
# 2    1999     3      Leonardo DiCaprio  United States
# 3    1999     4         Jerry Seinfeld  United States
# 4    1999     5       Steven Spielberg  United States
#
#                         career  tied                 title
# 192           Athlete (Boxing)     0  Floyd_Mayweather_Jr.
# 193                      Actor     0        George_Clooney
# 194                Personality     0          Kylie_Jenner
# 195                Personality     0        Judy_Sheindlin
# ...

# %%
df[df['rank']>3]['recipient']
# Out:
# 3         Jerry Seinfeld
# 4       Steven Spielberg
# 5            Spice Girls
# 6          Harrison Ford
# 7         Robin Williams
#              ...
# 197                   U2
# 198             Coldplay
# 199         Lionel Messi
# 200           Ed Sheeran
# 201    Cristiano Ronaldo
# Name: recipient, Length: 141, dtype: object

# %%
df.loc[df['rank']>3, ['rank', 'year']]
# Out:
#      rank  year
# 3       4  1999
# 4       5  1999
# 5       6  1999
# 6       7  1999
# 7       8  1999
# ..    ...   ...
# 197     6  2018
# 198     7  2018
# 199     8  2018
# 200     9  2018
# 201    10  2018
#
# [141 rows x 2 columns]

# %%
df[df['rank']>3]
# Out:
#      year  rank          recipient              country  \
# 3    1999     4     Jerry Seinfeld        United States
# 4    1999     5   Steven Spielberg        United States
# 5    1999     6        Spice Girls       United Kingdom
# 6    1999     7      Harrison Ford        United States
# 7    1999     8     Robin Williams        United States
# ..    ...   ...                ...                  ...
# 197  2018     6                 U2  Republic of Ireland
# 198  2018     7           Coldplay       United Kingdom
# 199  2018     8       Lionel Messi            Argentina
# 200  2018     9         Ed Sheeran       United Kingdom
# 201  2018    10  Cristiano Ronaldo             Portugal
#
#                              career  tied              title
# 3                             Actor     0     Jerry_Seinfeld
# 4                         Filmmaker     0   Steven_Spielberg
# 5                         Musicians     0        Spice_Girls
# ...

# %%
df[df['country'].str.contains('uNited', False)]['United']
# Out:
#      year  rank          recipient         country                     career  \
# 0    1999     1     Michael Jordan   United States  Sportsperson (Basketball)
# 1    1999     2      Oprah Winfrey   United States     Television Personality
# 2    1999     3  Leonardo DiCaprio   United States                      Actor
# 3    1999     4     Jerry Seinfeld   United States                      Actor
# 4    1999     5   Steven Spielberg   United States                  Filmmaker
# ..    ...   ...                ...             ...                        ...
# 194  2018     3       Kylie Jenner   United States                Personality
# 195  2018     4     Judy Sheindlin   United States                Personality
# 196  2018     5     Dwayne Johnson   United States                      Actor
# 198  2018     7           Coldplay  United Kingdom                  Musicians
# 200  2018     9         Ed Sheeran  United Kingdom                   Musician
#
#      tied              title
# ...

# %%
test_df = df[df['country'].str.contains('uNited', False)]

# %%
df[df['country'].str.contains('uNited', False)]
# Out:
#      year  rank          recipient         country                     career  \
# 0    1999     1     Michael Jordan   United States  Sportsperson (Basketball)
# 1    1999     2      Oprah Winfrey   United States     Television Personality
# 2    1999     3  Leonardo DiCaprio   United States                      Actor
# 3    1999     4     Jerry Seinfeld   United States                      Actor
# 4    1999     5   Steven Spielberg   United States                  Filmmaker
# ..    ...   ...                ...             ...                        ...
# 194  2018     3       Kylie Jenner   United States                Personality
# 195  2018     4     Judy Sheindlin   United States                Personality
# 196  2018     5     Dwayne Johnson   United States                      Actor
# 198  2018     7           Coldplay  United Kingdom                  Musicians
# 200  2018     9         Ed Sheeran  United Kingdom                   Musician
#
#      tied              title
# ...
